# %% [markdown]
# ![image.png](attachment:image.png)

# %%
val = "es$añ😮ㄱ"
print(val, type(val))
print(val.encode('utf-8'), type(val.encode('utf-8')))
print(val.encode('utf-8').decode('utf-8'), type(val.encode('utf-8').decode('utf-8')))
# Out:
# es$añ😮ㄱ <class 'str'>
# b'es$a\xc3\xb1\xf0\x9f\x98\xae\xe3\x84\xb1' <class 'bytes'>
# es$añ😮ㄱ <class 'str'>

# %% [markdown]
# ```Python
# import os
# entries = os.scandir('test') # returns an iterator of all the objects in a directory
# for e in entries:
#     if e.is_dir(): # directory
#         print(e.name)
#     elif e.is_file(): # file
#         print(e.name)
# ```
